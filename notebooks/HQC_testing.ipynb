# %%
# %run HQC.ipynb

def HQC_testing():
    
    # TEST KEYGEN
    
    # test key type and length
    C = HQC(w = 5, w_e = 5, w_r = 5, C = ProductCode(RMCode(r = 1, m = 4), RMCode(r = 1, m = 3)), key_type = 'pol')
    assert [_DetermineInput(C.pk[i], q = 2) == 'pol' for i in range(2)]
    assert [_DetermineInput(C.sk[i], q = 2) == 'pol' for i in range(2)]
    
    assert [len(C.pk[i].list()) == C.n for i in range(2)]
    assert [len(C.sk[i].list()) == C.n for i in range(2)]
    
    
    C = HQC(w = 5, w_e = 5, w_r = 5, C = ProductCode(RMCode(r = 1, m = 4), RMCode(r = 1, m = 3)), key_type = 'int')
    assert [_DetermineInput(C.pk[i], q = 2) == 'int' for i in range(2)]
    assert [_DetermineInput(C.sk[i], q = 2) == 'int' for i in range(2)]
    
    assert [len(C.pk[i]) == C.n for i in range(2)]
    assert [len(C.sk[i]) == C.n for i in range(2)]
    
    
    C = HQC(w = 5, w_e = 5, w_r = 5, C = ProductCode(RMCode(r = 1, m = 4), RMCode(r = 1, m = 3)), key_type = 'bin')
    assert [_DetermineInput(C.pk[i], q = 2) == 'bin' for i in range(2)]
    assert [_DetermineInput(C.sk[i], q = 2) == 'bin' for i in range(2)]
    
    assert [len(C.pk[i]) == C.n for i in range(2)]
    assert [len(C.sk[i]) == C.n for i in range(2)]
    
    
    # TEST ENCRYPT
    
    # message length
    # ...
    
    # ciphertext type and length
    
    C = HQC(w = 5, w_e = 5, w_r = 5, C = ProductCode(RMCode(r = 1, m = 4), RMCode(r = 1, m = 3)), key_type = 'pol')
    m = ''
    for i in range(C.k):
        e = ZZ.random_element(0,2)
        m = m + str(e)
    
    c = C.Encrypt(m, out = 'pol')
    assert [_DetermineInput(c[i], q = 2) == 'pol' for i in range(2)]    
    assert [len(c[i].list()) == C.n for i in range(2)]
    
    c = C.Encrypt(m, out = 'int')
    assert [_DetermineInput(c[i], q = 2) == 'int' for i in range(2)]    
    assert [len(c[i]) == C.n for i in range(2)]
    
    c = C.Encrypt(m, out = 'bin')
    assert [_DetermineInput(c[i], q = 2) == 'bin' for i in range(2)]    
    assert [len(c[i]) == C.n for i in range(2)]
    
    
    # TEST DECRYPT
    # encrypt out = ..., decrypt success?

    
    
HQC_testing()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/tmp/sage-9.4-current/local/lib/python3.9/multiprocessing/pool.py in next(self, timeout)
#     852             try:
# --> 853                 item = self._items.popleft()
#     854             except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/Dropbox/DTU/Speciale/HQC/HQC.ipynb in <module>
#      13     return k_random_list
#      14
# ---> 15 print(list(f([Integer(10),Integer(10),Integer(10)])))
#      16 #print(list(f(10)))
#
# /var/tmp/sage-9.4-current/local/lib/python3.9/site-packages/sage/parallel/multiprocessing_sage.py in parallel_iter(processes, f, inputs)
#      74     result = p.imap_unordered(call_pickled_function,
# ...
